# %%
import pandas as pd

# %%
sponsorships = pd.read_csv("NBASponserships1.csv")

# %%
sponsorships.columns
# Out:
# Index(['Team being Sponsored', 'Main Sponser's Name', 'Sponsorship Start Year',
#        'Tenure of Sponsorships', 'estimated Sponsorship Buying Cost',
#        'per year', 'Shared Sponsorships', 'Team Sponser is Shared With'],
#       dtype='object')

# %%
sponsorships.head(20)
# Out:
#          Team being Sponsored  \
# 0       (WNBA) Atlanta Dreams
# 1          (WNBA) Chicago Sky
# 2         (WNBA) Dallas Wings
# 3        (WNBA) Indiana Fever
# 4   (WNBA) Los Angeles Sparks
# 5       (WNBA) Las Vegas Aces
# 6       (WNBA) Minnesota Lynx
# 7     (WNBA) New York Liberty
# 8      (WNBA) Phoenix Mercury
# 9        (WNBA) Seattle Storm
# 10              Atlanta Hawks
# 11              Chicago Bulls
# 12            Dallas Mavricks
# 13      Golden State Warriors
# 14             Indiana Pacers
# 15         Los Angeles Lakers
# 16     Minnesota Timberwolves
# 17            New York Knicks
# 18      Oklahoma City Thunder
# 19               Phoenix Suns
#
#                                   Main Sponser's Name  \
# 0                                Gateway Center Arena
# 1                                  Wintrust Financial
# 2                                 College Park Center
# 3                                          Gainbridge
# ...
