# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sponsorships = pd.read_csv("NBASponsershipsRawData.csv")

# %%
sponsorships.columns
# Out:
# Index(['Team being Sponsored', 'Main Sponser's Name',
#        'Naming Rights Sponsorship Start Year', 'Team Sponorship Start Year',
#        'Tenure of NR Sponsorships (Years)',
#        'Est SS Buying Cost (USD$ Million)', 'Cost per Year (USD$ Million)',
#        'Shared Sponsorships', 'Team Sponser is Shared With',
#        'Company Worth in NR Sponsorship Year'],
#       dtype='object')

# %%
sponsorships.head(20)
# Out:
#          Team being Sponsored                           Main Sponser's Name  \
# 0       (WNBA) Atlanta Dreams                                Gateway Center
# 1          (WNBA) Chicago Sky                            Wintrust Financial
# 2         (WNBA) Dallas Wings                                  College Park
# 3        (WNBA) Indiana Fever       Gainbridge Insurance Agency /Group 1001
# 4   (WNBA) Los Angeles Sparks                                    crypto.com
# 5       (WNBA) Las Vegas Aces              Michelob Ultra /\nAnheuser-Busch
# 6       (WNBA) Minnesota Lynx                                        Target
# 7     (WNBA) New York Liberty                                 Barclays Bank
# 8      (WNBA) Phoenix Mercury                                     Footprint
# 9        (WNBA) Seattle Storm                                        Amazon
# 10              Atlanta Hawks                                    State Farm
# 11              Chicago Bulls                               United Airlines
# 12            Dallas Mavricks                             American Airlines
# 13      Golden State Warriors                                         Chase
# 14             Indiana Pacers       Gainbridge Insurance Agency /Group 1001
# 15         Los Angeles Lakers                                    crypto.com
# 16     Minnesota Timberwolves                                        Target
# 17            New York Knicks  Madison Square Garden Sports / New York City
# 18      Oklahoma City Thunder                                        Paycom
# 19               Phoenix Suns                                     Footprint
#
#    Naming Rights Sponsorship Start Year Team Sponorship Start Year  \
# 0                                  2019                       2021
# 1                                  2016                       2018
# 2                                  2012                       2016
# 3                                  2021                       2021
# 4                                  2021                       2021
# 5                                  2021                       2021
# 6                                  1990                       1990
# 7                                  2007                       2020
# 8                                  2021                       2021
# 9                                  2020                       2021
# 10                                 2018                       2018
# 11                                 1994                       2013
# 12                                 1999                       2001
# 13                                 2016                       2019
# 14                                 2021                       2021
# 15                                 2021                       2021
# 16                                 1990                       1990
# 17                        Not Sponsored              Not Sponsored
# 18                                 2021                       2021
# 19                                 2021                       2021
#
#    Tenure of NR Sponsorships (Years)  Est SS Buying Cost (USD$ Million)  \
# 0                                N/A                                NaN
# 1                                 15                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                 20                              700.0
# 5                                NaN                                NaN
# 6                                 33                                NaN
# 7                                 20                              200.0
# 8                                N/A                                NaN
# 9                                NaN                              400.0
# 10                                20                              175.0
# 11                                20                               36.0
# 12                                30                              195.0
# 13                                20                              300.0
# 14                               NaN                                NaN
# 15                                20                              700.0
# 16                                33                                NaN
# 17                               NaN                                NaN
# 18                                15                              100.0
# 19                               NaN                                NaN
#
#     Cost per Year (USD$ Million) Shared Sponsorships  \
# 0                            NaN                  No
# 1                            NaN                  No
# 2                            NaN                  No
# 3                            NaN                 Yes
# 4                          35.00                 Yes
# 5                            NaN                  No
# 6                           1.50                 Yes
# 7                          10.00                  No
# 8                            NaN                 Yes
# 9                            NaN                  No
# 10                          8.75                  No
# 11                          1.80                  No
# 12                          5.00                  No
# 13                         15.00                  No
# 14                           NaN                 Yes
# 15                         35.00                 Yes
# 16                          1.50                 Yes
# 17                           NaN                  No
# 18                          6.60                  No
# 19                           NaN                 Yes
#
#    Team Sponser is Shared With Company Worth in NR Sponsorship Year
# 0                   not shared                          -740,936.00
# 1                   not shared                     1,138,000,000.00
# 2                   not shared                     1,146,387,940.74
# 3               Indiana Pacers                    44,000,000,000.00
# 4           Los Angeles Lakers                 3,000,000,000,000.00
# 5                   not shared                    31,207,000,000.00
# 6       Minnesota Timberwolves                    28,000,000,000.00
# 7                   not shared                    66,570,000,000.00
# 8                 Phoenix Suns                          -137,572.00
# 9                   not shared                 1,629,280,000,000.00
# 10                  not shared                   100,900,000,000.00
# 11                  not shared                      -613,000,000.00
# 12                  not shared                       985,000,000.00
# 13                  not shared                   315,720,000,000.00
# 14               Indiana Fever                    44,000,000,000.00
# 15          Los Angeles Sparks                 3,000,000,000,000.00
# 16              Minnesota Lynx                    28,000,000,000.00
# 17                  not shared                                  NaN
# 18                  not shared                    24,030,000,000.00
# 19             Phoenix Mercury                          -137,572.00

# %%
droppedSponsorships = sponsorships.dropna(axis=0)

# %%
droppedSponsorships
# Out:
#          Team being Sponsored Main Sponser's Name  \
# 4   (WNBA) Los Angeles Sparks          crypto.com
# 7     (WNBA) New York Liberty       Barclays Bank
# 10              Atlanta Hawks          State Farm
# 11              Chicago Bulls     United Airlines
# 12            Dallas Mavricks   American Airlines
# 13      Golden State Warriors               Chase
# 15         Los Angeles Lakers          crypto.com
# 18      Oklahoma City Thunder              Paycom
#
#    Naming Rights Sponsorship Start Year Team Sponorship Start Year  \
# 4                                  2021                       2021
# 7                                  2007                       2020
# 10                                 2018                       2018
# 11                                 1994                       2013
# 12                                 1999                       2001
# 13                                 2016                       2019
# 15                                 2021                       2021
# 18                                 2021                       2021
#
#    Tenure of NR Sponsorships (Years)  Est SS Buying Cost (USD$ Million)  \
# 4                                 20                              700.0
# 7                                 20                              200.0
# 10                                20                              175.0
# 11                                20                               36.0
# 12                                30                              195.0
# 13                                20                              300.0
# 15                                20                              700.0
# 18                                15                              100.0
#
#     Cost per Year (USD$ Million) Shared Sponsorships  \
# 4                          35.00                 Yes
# 7                          10.00                  No
# 10                          8.75                  No
# 11                          1.80                  No
# 12                          5.00                  No
# 13                         15.00                  No
# 15                         35.00                 Yes
# 18                          6.60                  No
#
#    Team Sponser is Shared With Company Worth in NR Sponsorship Year
# 4           Los Angeles Lakers                 3,000,000,000,000.00
# 7                   not shared                    66,570,000,000.00
# 10                  not shared                   100,900,000,000.00
# 11                  not shared                      -613,000,000.00
# 12                  not shared                       985,000,000.00
# 13                  not shared                   315,720,000,000.00
# 15          Los Angeles Sparks                 3,000,000,000,000.00
# 18                  not shared                    24,030,000,000.00

# %%
droppedSponsorships.columns
# Out:
# Index(['Team being Sponsored', 'Main Sponser's Name',
#        'Naming Rights Sponsorship Start Year', 'Team Sponorship Start Year',
#        'Tenure of NR Sponsorships (Years)',
#        'Est SS Buying Cost (USD$ Million)', 'Cost per Year (USD$ Million)',
#        'Shared Sponsorships', 'Team Sponser is Shared With',
#        'Company Worth in NR Sponsorship Year'],
#       dtype='object')

# %%
groupedSponsors = droppedSponsorships.groupby("Team being Sponsored")["Cost per Year (USD$ Million)"]

# %%
#x_axis = list(droppedSponsorships.columns[2:])

# %%
#x_axis

# %%
#y_axis = "Team being Sponsored"

# %%
droppedSponsorships.set_index("Team being Sponsored", inplace=True)

# %%
droppedSponsorships.plot(kind = "bar")
plt.xticks(rotation = 79)
plt.show()

# %%
yearlySponsors = droppedSponsorships.groupby("Main Sponser's Name")["Cost per Year (USD$ Million)"]

# %%
droppedSponsorships.set_index("Main Sponser's Name", inplace=True)

# %%
yearlySponsors.plot(kind = "pie")
# Out:
# Main Sponser's Name
# American Airlines    AxesSubplot(0.22375,0.11;0.5775x0.77)
# Barclays Bank        AxesSubplot(0.22375,0.11;0.5775x0.77)
# Chase                AxesSubplot(0.22375,0.11;0.5775x0.77)
# Paycom               AxesSubplot(0.22375,0.11;0.5775x0.77)
# State Farm           AxesSubplot(0.22375,0.11;0.5775x0.77)
# United Airlines      AxesSubplot(0.22375,0.11;0.5775x0.77)
# crypto.com           AxesSubplot(0.22375,0.11;0.5775x0.77)
# Name: Cost per Year (USD$ Million), dtype: object
